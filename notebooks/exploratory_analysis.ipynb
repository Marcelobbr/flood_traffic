# %%
import os
import pandas as pd
import seaborn as sns
import pickle
import numpy as np
import statsmodels.api as sm
import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
datapath = "../data/"
outputs = "../outputs/"

# %%
df_miraflores = pd.read_csv(os.path.join(datapath,'19-07-miraflores-alerts.csv'))
df_montevideo = pd.read_csv(os.path.join(datapath,'19-07-montevideo-alerts.csv'))

# %%
df_miraflores.head()
# Out:
#                                    uuid   latitude  longitude           type  \
# 0  18d86b5a-b40d-343c-9914-b1f9e96558f2 -12.125656 -77.038671       ACCIDENT
# 1  bacbbb1e-b77e-3cb5-846b-adb8850b6056 -12.135582 -77.029071       ACCIDENT
# 2  4894a737-f2a6-3a97-a4cf-2e74ddcc6ffe -12.119155 -77.046048       ACCIDENT
# 3  5f44b434-8e05-363d-acb7-2e973b532247 -12.128255 -77.005020  WEATHERHAZARD
# 4  0f45d1b9-39ce-33cd-b294-ea7f5cef242e -12.110754 -77.053766  WEATHERHAZARD
#
#                        subtype  interactions                   street  \
# 0                          NaN            63  Vía Expresa Costa Verde
# 1               ACCIDENT_MINOR            61  Vía Expresa Costa Verde
# 2               ACCIDENT_MINOR            49  Vía Expresa Costa Verde
# 3  HAZARD_ON_ROAD_CONSTRUCTION            48    Av. Alfredo Benavides
# 4   HAZARD_ON_ROAD_CAR_STOPPED            48  Vía Expresa Costa Verde
#
#    reliability               start_time                 end_time
# ...

# %%
df_miraflores.tail()
# Out:
#                                        uuid   latitude  longitude type  \
# 32400  c737f453-8c2c-36d1-907a-775a5dd0969a -12.125435 -77.012968  JAM
# 32401  b3d72185-8d2a-3add-ae57-34afc0afb8cb -12.123239 -77.018999  JAM
# 32402  901be114-0347-3f30-aaaf-ad76e3fd6af1 -12.118998 -77.034579  JAM
# 32403  eab7fc92-a02a-38f6-9a93-90436197a694 -12.128750 -77.016577  JAM
# 32404  58416dc7-8c12-3a2e-8763-298ddcc140b2 -12.124424 -77.030428  JAM
#
#                     subtype  interactions                        street  \
# 32400     JAM_HEAVY_TRAFFIC             1  Av. General Ernesto Montagne
# 32401  JAM_MODERATE_TRAFFIC             1             Av. Ricardo Palma
# 32402  JAM_MODERATE_TRAFFIC             1                Av. José Pardo
# 32403     JAM_HEAVY_TRAFFIC             1       Manuel Augusto Olaechea
# 32404     JAM_HEAVY_TRAFFIC             1         Av. Alfredo Benavides
#
#        reliability               start_time                 end_time
# ...

# %%
df_montevideo.head()
# Out:
#                                    uuid   latitude  longitude           type  \
# 0  8462624d-5c9d-318a-823d-d53f785e495d -34.907669 -56.176553  WEATHERHAZARD
# 1  e9892303-a651-32cd-8399-5c5dd0c9bb8e -34.923522 -56.161606  WEATHERHAZARD
# 2  67f92a84-1a74-331c-8272-cb2330254283 -34.895943 -56.167902  WEATHERHAZARD
# 3  ecf70f1c-4b17-3410-91f9-a7efd7bf1aed -34.875881 -56.180787  WEATHERHAZARD
# 4  5a0e0e71-d29d-3e28-bbed-e371580235e6 -34.893478 -56.159235  WEATHERHAZARD
#
#                    subtype  interactions                     street  \
# 0  HAZARD_ON_ROAD_POT_HOLE           108                  Canelones
# 1  HAZARD_ON_ROAD_POT_HOLE            90  Francisco García Cortinas
# 2  HAZARD_ON_ROAD_POT_HOLE            84               Daniel Muñoz
# 3  HAZARD_ON_ROAD_POT_HOLE            76        Av. Gral. Garibaldi
# 4  HAZARD_ON_ROAD_POT_HOLE            73  Av. Dr. Américo Ricaldoni
#
#    reliability               start_time                 end_time
# ...

# %%
df_montevideo.tail()
# Out:
#                                        uuid   latitude  longitude  \
# 26537  0e932b85-1e36-3d43-a9ce-95f7e5f424e2 -34.876336 -56.148672
# 26538  b62b3da1-7b4d-3356-9afa-444ec59d8c1a -34.868936 -56.123807
# 26539  d5cba684-c2cc-3b6d-a5ca-75da556e121b -34.818916 -56.214631
# 26540  b1f5df16-dde6-3110-bdb5-74a2ead73901 -34.868061 -56.063304
# 26541  1d519a85-2db8-3092-ac48-de214cdc1e1b -34.906053 -56.193123
#
#                 type                      subtype  interactions  \
# 26537    ROAD_CLOSED            ROAD_CLOSED_EVENT             1
# 26538    ROAD_CLOSED            ROAD_CLOSED_EVENT             1
# 26539    ROAD_CLOSED            ROAD_CLOSED_EVENT             1
# 26540  WEATHERHAZARD                          NaN             1
# 26541  WEATHERHAZARD  HAZARD_ON_ROAD_CONSTRUCTION             1
#
#                      street  reliability               start_time  \
# 26537        Carlos Crocker            6  2019-07-06 08:55:00.000
# ...

# %%
df_miraflores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32405 entries, 0 to 32404
# Data columns (total 10 columns):
# uuid            32405 non-null object
# latitude        32405 non-null float64
# longitude       32405 non-null float64
# type            32405 non-null object
# subtype         30961 non-null object
# interactions    32405 non-null int64
# street          32134 non-null object
# reliability     32405 non-null int64
# start_time      32405 non-null object
# end_time        32405 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 2.5+ MB

# %%
df_montevideo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26542 entries, 0 to 26541
# Data columns (total 10 columns):
# uuid            26542 non-null object
# latitude        26542 non-null float64
# longitude       26542 non-null float64
# type            26542 non-null object
# subtype         24871 non-null object
# interactions    26542 non-null int64
# street          26198 non-null object
# reliability     26542 non-null int64
# start_time      26542 non-null object
# end_time        26542 non-null object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 2.0+ MB

# %%
df_miraflores.dtypes
# Out:
# uuid             object
# latitude        float64
# longitude       float64
# type             object
# subtype          object
# interactions      int64
# street           object
# reliability       int64
# start_time       object
# end_time         object
# dtype: object

# %%
df_montevideo.dtypes
# Out:
# uuid             object
# latitude        float64
# longitude       float64
# type             object
# subtype          object
# interactions      int64
# street           object
# reliability       int64
# start_time       object
# end_time         object
# dtype: object

# %%
df_miraflores.describe()
# Out:
#            latitude     longitude  interactions   reliability
# count  32405.000000  32405.000000  32405.000000  32405.000000
# mean     -12.119841    -77.027472      1.844839      5.827372
# std        0.008257      0.010909      2.939573      1.477585
# min      -12.169412    -77.055753      1.000000      5.000000
# 25%      -12.126514    -77.032454      1.000000      5.000000
# 50%      -12.120594    -77.028134      1.000000      5.000000
# 75%      -12.113341    -77.021434      1.000000      6.000000
# max      -12.098063    -77.001493     63.000000     10.000000

# %%
df_montevideo.describe()
# Out:
#            latitude     longitude  interactions   reliability
# count  26542.000000  26542.000000  26542.000000  26542.000000
# mean     -34.879514    -56.166598      2.390965      6.074523
# std        0.028245      0.040492      4.795191      1.515535
# min      -34.929126    -56.350176      1.000000      5.000000
# 25%      -34.899780    -56.189392      1.000000      5.000000
# 50%      -34.887299    -56.165379      1.000000      6.000000
# 75%      -34.867615    -56.147680      1.000000      6.000000
# max      -34.699358    -56.031563    108.000000     10.000000

# %%
for cat in df_miraflores.columns:
    print("Number of levels in category '{0}': \b {1:2.2f} ".format(cat, df_miraflores[cat].unique().size))
# Out:
#  32404.00
#  17008.00
#  18873.00
#  4.00
#  25.00
#  49.00
#  289.00
#  6.00
#  15643.00
#  15550.00

# %%
for cat in df_montevideo.columns:
    print("Number of levels in category '{0}': \b {1:2.2f} ".format(cat, df_montevideo[cat].unique().size))
# Out:
#  26540.00
#  16796.00
#  17793.00
#  4.00
#  24.00
#  69.00
#  1157.00
#  6.00
#  11921.00
#  11893.00

# %% [raw]
# #correlation matrix
# corrmat = df_miraflores.corr()
# f, ax = plt.subplots(figsize=(12, 9))
# sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#missing data
total = df_miraflores.isnull().sum().sort_values(ascending=False)
percent = (df_miraflores.isnull().sum()/df_miraflores.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# subtype        1444  0.044561
# street          271  0.008363
# end_time          0  0.000000
# start_time        0  0.000000
# reliability       0  0.000000
# interactions      0  0.000000
# type              0  0.000000
# longitude         0  0.000000
# latitude          0  0.000000
# uuid              0  0.000000
